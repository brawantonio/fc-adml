# %% [markdown]
# # Poniendo en práctica lo aprendido

# %% [markdown]
# El ejercicio de las siguientes dos clases consistirá en poner en práctica lo aprendido durante las clases pasadas (cálculo de cuantiles, momentos, identificación de valores atípicos) y vamos a añadir la parte computacional (graficar principalmente).
#
# Este ejercicio yo lo realicé hace varios años en un curso de cómputo aquí en la facultad con un profesor excelente, pero utilizamos herramientas un poco más _arcaicas_ (`awk`). Esta vez repetiremos el ejercicio juntos pero con pandas.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import folium

# %% [markdown]
# ## Elecciones presidenciales del 2006

# %% [markdown]
# Comenzaremos por cargar el archivo de datos. Se encuentra abajo. Les voy a ayudar pues no es un csv, pero es basicamente lo mismo, sólo que el lugar de usar comas utiliza esta cosa: | (pipe).
#
# El contenido del archivo se encuentra explicado por el mismisimo IFE (cuando aún era IFE, en mis tiempos) en el pdf explicacion.pdf. Léanlo para entender lo que es cada columna (**en verdad háganlo, porque con el ID no les va a ser suficiente. Y a la mejor después de leerlo de todos modos no queda claro...**), conserven los nombres de las columnas aunque sean horribles y largos. Utilicen pues la función `pd.read_csv()` con los argumentos adecuados para cargar el csv a una variable llamada datos.
#
# **TRUCO**: si colocan el cursor en el paréntesis de la función y presionan shift+tab les va a decir cuales son los argumentos que la función espera. Es superútil!

# %%
datos = pd.read_csv('Computos2006-Presidente.txt', delimiter='|')
print("Número de entradas:", datos.shape[0])
datos.head()
# Out:
# Número de entradas: 130788
#    ID_ESTADO  DISTRITO  SECCION  ID_CASILLA TIPO_CASILLA  EXT_CONTIGUA  \
# 0          1         1        0           1            B             0
# 1          1         1      338           1            B             0
# 2          1         1      338           1            C             0
# 3          1         1      339           1            B             0
# 4          1         1      339           1            C             0
#
#    TIPO_CANDIDATURA  TIPO_ACTA  LISTA_NOMINAL  NO_VOTOS_NULOS  \
# 0                 6        NaN            120             0.0
# 1                 1        1.0            689            12.0
# 2                 1        1.0            689             7.0
# 3                 1        1.0            630             0.0
# 4                 1        1.0            631             6.0
#
#           ...           ORDEN    PAN   APM   PBT    NA  ASDC  MUNICIPIO  \
# 0         ...               1   53.0   4.0  18.0   0.0   1.0          0
# 1         ...               1  202.0  45.0  65.0  12.0  12.0          2
# 2         ...               2  175.0  38.0  56.0   3.0   8.0          2
# 3         ...               3  165.0  50.0  48.0   7.0  13.0          2
# 4         ...               4  174.0  64.0  32.0   9.0   7.0          2
#
#    PAQUETE_ENTREGADO  CASILLA_INSTALADA           FECHA_HORA
# 0                NaN                NaN  05/07/2006 23:22:10
# 1                1.0                1.0  05/07/2006 08:17:05
# 2                1.0                1.0  05/07/2006 08:22:24
# 3                1.0                1.0  05/07/2006 08:24:47
# 4                1.0                1.0  05/07/2006 08:25:03
#
# [5 rows x 23 columns]

# %% [markdown]
# Como pueden ver, se han cargado las 23 columnas descritas en el pdf. Para que sea un poco más entendible a nosotros, vamos a comenzar por reemplazar la columna de ID_ESTADO por ESTADO. El siguiente diccionario mapea los identificadores a los estados correspondientes

# %%
id2state = {1: 'Aguascalientes', 2:'Baja California', 3: 'Baja California Sur', 4: 'Campeche',
           5: 'Coahuila', 6: 'Colima', 7: 'Chiapas', 8: 'Chihuahua', 9:'CDMX', 10: 'Durango',
           11: 'Guanajuato', 12: 'Guerrero', 13: 'Hidalgo', 14: 'Jalisco', 15: 'México',
           16: 'Michoacán', 17: 'Morelos', 18: 'Nayarit', 19: 'Nuevo León', 20: 'Oaxaca',
           21: 'Puebla', 22: 'Querétaro', 23: 'Quintana Roo', 24: 'San Luis Potosí',
           25: 'Sinaloa', 26: 'Sonora', 27: 'Tabasco', 28: 'Tamaulipas', 29: 'Tlaxcala',
           30: 'Veracruz', 31: 'Yucatán', 32: 'Zacatecas'}

# %%
datos = datos.replace({'ID_ESTADO': id2state})
datos.head()
# Out:
#         ID_ESTADO  DISTRITO  SECCION  ID_CASILLA TIPO_CASILLA  EXT_CONTIGUA  \
# 0  Aguascalientes         1        0           1            B             0
# 1  Aguascalientes         1      338           1            B             0
# 2  Aguascalientes         1      338           1            C             0
# 3  Aguascalientes         1      339           1            B             0
# 4  Aguascalientes         1      339           1            C             0
#
#    TIPO_CANDIDATURA  TIPO_ACTA  LISTA_NOMINAL  NO_VOTOS_NULOS  \
# 0                 6        NaN            120             0.0
# 1                 1        1.0            689            12.0
# 2                 1        1.0            689             7.0
# 3                 1        1.0            630             0.0
# 4                 1        1.0            631             6.0
#
#           ...           ORDEN    PAN   APM   PBT    NA  ASDC  MUNICIPIO  \
# 0         ...               1   53.0   4.0  18.0   0.0   1.0          0
# 1         ...               1  202.0  45.0  65.0  12.0  12.0          2
# 2         ...               2  175.0  38.0  56.0   3.0   8.0          2
# 3         ...               3  165.0  50.0  48.0   7.0  13.0          2
# 4         ...               4  174.0  64.0  32.0   9.0   7.0          2
#
#    PAQUETE_ENTREGADO  CASILLA_INSTALADA           FECHA_HORA
# 0                NaN                NaN  05/07/2006 23:22:10
# 1                1.0                1.0  05/07/2006 08:17:05
# 2                1.0                1.0  05/07/2006 08:22:24
# 3                1.0                1.0  05/07/2006 08:24:47
# 4                1.0                1.0  05/07/2006 08:25:03
#
# [5 rows x 23 columns]

# %% [markdown]
# El archivo contiene sólo los datos para elección presidencial, pero están divididos en dos grupos: Voto extranjero y no extranjero. genere un nuevo DF donde estén los votos del extranjero únicamente, y uno en que estén los votos restantes. En ambos DF puede eliminar la columna `TIPO_CANDIDATURA`. Es una buena práctica en general conservar el arreglo original (nótese que nosotros ya rompimos esa regla al reemplazar el nombre de una de las columnas, pero toda la información sigue ahí)

# %%
#Su respuesta aquí
national = datos['SECCION'] == 0
foreign = datos['SECCION'] != 0
votoExtranjero = datos[national]
votoLocal = datos[foreign]

votoExtranjero.drop('TIPO_CANDIDATURA', axis=1)
votoLocal.drop('TIPO_CANDIDATURA', axis=1)

votoExtranjero.head()
# Out:
#             ID_ESTADO  DISTRITO  SECCION  ID_CASILLA TIPO_CASILLA  \
# 0      Aguascalientes         1        0           1            B
# 369    Aguascalientes         2        0           1            B
# 789    Aguascalientes         3        0           1            B
# 1229  Baja California         1        0           1            B
# 1621  Baja California         2        0           1            B
#
#       EXT_CONTIGUA  TIPO_CANDIDATURA  TIPO_ACTA  LISTA_NOMINAL  \
# 0                0                 6        NaN            120
# 369              0                 6        NaN             89
# 789              0                 6        NaN            203
# 1229             0                 6        NaN             87
# 1621             0                 6        NaN            168
#
#       NO_VOTOS_NULOS         ...           ORDEN    PAN   APM   PBT   NA  \
# 0                0.0         ...               1   53.0   4.0  18.0  0.0
# 369              0.0         ...               1   50.0   3.0  14.0  0.0
# 789              0.0         ...               1  118.0   9.0  37.0  0.0
# 1229             0.0         ...               1   45.0   6.0  21.0  1.0
# 1621             0.0         ...               1   98.0  10.0  39.0  2.0
#
#       ASDC  MUNICIPIO  PAQUETE_ENTREGADO  CASILLA_INSTALADA  \
# 0      1.0          0                NaN                NaN
# 369    6.0          0                NaN                NaN
# 789    6.0          0                NaN                NaN
# 1229   1.0          0                NaN                NaN
# 1621   3.0          0                NaN                NaN
#
#                FECHA_HORA
# 0     05/07/2006 23:22:10
# 369   06/07/2006 02:03:05
# 789   05/07/2006 18:09:48
# 1229  05/07/2006 14:53:02
# 1621  06/07/2006 05:34:11
#
# [5 rows x 23 columns]

# %% [markdown]
# ## Estadística general

# %% [markdown]
# Como primera tarea, verifique que los datos que tenemos coinciden con lo reportado por el IFE. Es decir, busque los porcentajes de votaciones para cada partido, el número de votos totales y vea que son los mismos que el IFE anunció. Observe que hay campos de "Votos Nulos", campos de "Votos totales" y campos de "Votos totales". Al comparar con lo reportado en otros lados usted comprenderá mejor lo que significa cada campo.

# %%
# Su respuesta aquí
votes_total = datos['TOTAL_VOTOS'].sum()
votes_valid = datos['NO_VOTOS_VALIDOS'].sum()

Partidos = ['PAN', 'APM', 'PBT', 'NA', 'ASDC']
for key in Partidos:
    votes_party = datos[key].sum() 
    print('Fracción de votos totales para ', key, votes_party/votes_total, '. Fracción válida: ', votes_party/votes_valid)
print('Votos totales: ', votes_total,'. Votos válidos: ', votes_valid)
# Out:
# Fracción de votos totales para  PAN 0.35893298613525554 . Fracción válida:  0.3668742499703693
# Fracción de votos totales para  APM 0.22256871893164806 . Fracción válida:  0.22749297216763645
# Fracción de votos totales para  PBT 0.3530960327122459 . Fracción válida:  0.3609081560422629
# Fracción de votos totales para  NA 0.009614531935601368 . Fracción válida:  0.009827250013072705
# Fracción de votos totales para  ASDC 0.02701158867383999 . Fracción válida:  0.027609210404219778
# Votos totales:  41791322 . Votos válidos:  40886718.0

# %% [markdown]
# ## Búsqueda de anomalías

# %% [markdown]
# Lo primero es ver el tipo de datos que tenemos ahora. Conteste las siguientes preguntas.

# %% [markdown]
# #### 1.1 NaN's (información faltante)

# %% [markdown]
# Hay Nan's en algunas columnas? Cuáles? Qué importancia tiene esto?

# %%
# Su respuesta aquí
NanColumns = datos.columns[datos.isnull().any()].tolist()
for key in NanColumns:
    l=len(datos[datos[key].isnull()])
    print(l, ' datos faltantes en: ', key)
# Out:
# 300  datos faltantes en:  TIPO_ACTA
# 11  datos faltantes en:  NO_VOTOS_NULOS
# 11  datos faltantes en:  NO_VOTOS_CAN_NREG
# 11  datos faltantes en:  NO_VOTOS_VALIDOS
# 11  datos faltantes en:  PAN
# 11  datos faltantes en:  APM
# 11  datos faltantes en:  PBT
# 11  datos faltantes en:  NA
# 11  datos faltantes en:  ASDC
# 300  datos faltantes en:  PAQUETE_ENTREGADO
# 300  datos faltantes en:  CASILLA_INSTALADA

# %% [markdown]
# #### 1.2 Lista nominal

# %% [markdown]
# Calcule el porcentaje de participación al comparar con la gente que estaba anunciada para votar: es decir, sume los valores de las listas nominales y comparelos con los votos totales. Este número **no** puede ser mayor al número de votos, y note porfavor que sólo porque el resultado global acatará esto, no quiere decir que en cada casilla haya ocurrido. Busque **casilla por casilla** si en verdad hay menos votos que gente en las listas nominales.

# %%
r = datos['TOTAL_VOTOS'].sum()/datos['LISTA_NOMINAL'].sum()
print('Fracción de votos totales contra lista nominal: ', r)
# Out:
# Fracción de votos totales contra lista nominal:  0.5855227898114075

# %%
datos_anomalos = datos[datos.apply(lambda x: x['TOTAL_VOTOS'] > x['LISTA_NOMINAL'], axis=1 )]
print('Número de casillas con más votos que lista nominal: ',len(datos_anomalos))
print('Número de votos añadidos: ', datos_anomalos['TOTAL_VOTOS'].sum())
print('Número de votos al pan: ', datos_anomalos['PAN'].sum())
# Out:
# Número de casillas con más votos que lista nominal:  939
# Número de votos añadidos:  583831
# Número de votos al pan:  240088.0

# %% [markdown]
# ## Estadística por estados

# %% [markdown]
# #### 2.1 Participación

# %% [markdown]
# Comienze por calcular cuántos votos hubo por estado (busque lo que hace la función `groupby` de pandas) y comparelos con la lista nominal de dicho estado (la suma, vaya). Cuál fue el estado con la participación más alta?

# %%
# Su respuesta aquí
States_groups = votoLocal.groupby('ID_ESTADO').mean()
States_groups[['TOTAL_VOTOS', 'LISTA_NOMINAL']].sort_values(['TOTAL_VOTOS'], ascending = False)
# Out:
#                      TOTAL_VOTOS  LISTA_NOMINAL
# ID_ESTADO
# CDMX                  395.960272     581.982061
# Tabasco               379.263947     555.909242
# México                367.236996     589.832227
# Yucatán               366.631041     547.638941
# Querétaro             365.949529     572.680532
# Jalisco               359.187245     581.677419
# Nuevo León            349.795212     582.851801
# Morelos               343.480116     570.099418
# Colima                339.275000     539.394737
# Aguascalientes        337.339315     573.644372
# Campeche              337.093851     521.255663
# Quintana Roo          334.999131     587.083406
# Puebla                329.325361     570.484637
# Tlaxcala              327.550319     562.682907
# Veracruz              320.970755     531.916849
# Guanajuato            319.950016     559.014701
# Sonora                310.844874     555.500666
# Hidalgo               309.962611     531.651689
# Tamaulipas            309.164269     561.225839
# San Luis Potosí       308.084224     515.445740
# Coahuila              301.094590     553.067703
# Oaxaca                300.866801     518.085676
# Michoacán             275.611450     544.551431
# Baja California Sur   273.105740     498.321752
# Baja California       267.960203     570.908552
# Chiapas               266.660101     543.561400
# Nayarit               262.571121     483.875718
# Durango               256.079749     471.073477
# Chihuahua             245.220579     503.111135
# Sinaloa               228.383737     403.427773
# Guerrero              221.713934     477.319615
# Zacatecas             219.110693     415.049708

# %% [markdown]
# ## Mapa de preferencias

# %% [markdown]
# Utilice Folium para indicar _qué color era cada estado_. Es decir, utilice `groupby` nuevamente para clasificar por estados, y encuentre el máximo de las columnas "PAN", "APM", "PBT", "NA" y "ASDC". Puede utilizar el vector de colores definido al principio para colorear los estados.

# %%
def party2color(feature, mayorias):
    colors = {'PAN': "#2f35e5", 'APM': "#32d24b", 'PBT': "#e6d775"} #Los demás no van a aparecer.
    return colors[mayorias.loc[feature["properties"]["NOM_ENT"]]]

# %%
# Calcule la serie de mayorías: Como ID debe estar el estado, como columna una llamada "Ganador" que contenga
# el nombre de la columna ganadora de votos
Preferences = States_groups[Partidos]
Ganador = Preferences.idxmax(axis=1)
Ganador.head()
# Out:
# ID_ESTADO
# Aguascalientes         PAN
# Baja California        PAN
# Baja California Sur    PBT
# CDMX                   PBT
# Campeche               PBT
# dtype: object

# %%
mexmap = folium.Map([23, -102], zoom_start=5)
folium.GeoJson('mexican_states.geojson',
               name='geojson',
               style_function= lambda feature: {
                                'fillColor': party2color(feature, Ganador),
                                'color': 'black',
                                'weight': 2,
                                'dashArray': '5, 5'
    }
              ).add_to(mexmap)

folium.LayerControl().add_to(mexmap)
mexmap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
